# %%
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
from matplotlib.patches import Ellipse
#from mpl_toolkits.axisartist.axislines import SubplotZero
from matplotlib.path import Path
from matplotlib.patches import PathPatch

# %%
# Parameters for matplotlib (these should be the same as the ones used for SHD)
fontsize = 20
matplotlib.rcParams.update({
    "font.size": fontsize,
    "axes.titlesize": fontsize,
    "axes.labelsize": fontsize, #* 2,
    "xtick.labelsize": fontsize,
    "ytick.labelsize": fontsize,
    "xtick.major.size": fontsize * .8,
    "ytick.major.size": fontsize * .8,
    "legend.fontsize": fontsize,
    #"font.family": "Times new Roman",
    "figure.dpi": 100,
    "savefig.dpi": 300,
    #"text.usetex": True,
    "path.simplify": True,
    "figure.figsize": (8, 6)
})

plt.rcParams["figure.facecolor"] = "w"


# Class to deal in an easy way with number of digits in colorbars (used for ULs and sigma maps)
class FormatScalarFormatter(matplotlib.ticker.ScalarFormatter):
            def __init__(self, fformat="%1.1f", offset=True, mathText=True):
                self.fformat = fformat
                matplotlib.ticker.ScalarFormatter.__init__(self,useOffset=offset,
                                                        useMathText=mathText)
            def _set_format(self):
                self.format = self.fformat
                if self._useMathText:
                    #self.format = '$%s$' % matplotlib.ticker._mathdefault(self.format)
                    self.format = '$%s$' % ('\\mathdefault{%s}' % self.format)

# %% [markdown]
# # Chapter 1

# %% [markdown]
# ## GW polarisations

# %% [markdown]
# ### $+$ polarisaton

# %%
fig, ax = plt.subplots(subplot_kw={'aspect': 'equal'}, figsize = (8,6))

ellipse = Ellipse((0, 0), 4, 2, angle=0., fill = False, color = "black")
ax.add_artist(ellipse)
ellipse = Ellipse((0, 0), 4, 2, angle=90., fill = False, color = "black", linestyle = "dotted")
ax.add_artist(ellipse)
ellipse = Ellipse((2.25, 2.25), 0.4, 0.4, angle=90., fill = False, color = "black")
ax.add_artist(ellipse)
ellipse = Ellipse((2.25, 2.25), 0.1, 0.1, angle=90., fill = True, color = "black")
ax.add_artist(ellipse)

# Move left y-axis and bottom x-axis to centre, passing through (0,0)
ax.spines['left'].set_position('center')
ax.spines['bottom'].set_position('center')

# Eliminate upper and right axes
ax.spines['right'].set_color('none')
ax.spines['top'].set_color('none')

plt.tick_params(left = False, bottom = False, labelleft=False, labelbottom = False)

lim = 2.5
dx = 0.1
ax.set_xlim(-lim, lim)
ax.set_ylim(-lim, lim)
ax.arrow(lim-dx, 0., dx, 0., width = 0.1, head_width=0.1, head_length=0.1, length_includes_head=True, color="black")
ax.arrow(0, lim-dx, 0., dx, width = 0.1, head_width=0.1, head_length=0.1, length_includes_head=True, color="black")
plt.annotate("X", (lim, -1*dx))
plt.annotate("Y", (-2*dx, lim))
plt.annotate("tensor-plus", (0.75, -lim))

#plt.axis('off')

plt.savefig("./Plus_polarisation.pdf")
plt.savefig("./Plus_polarisation.svg")
plt.show()
plt.close()

# %% [markdown]
# ### $\times$ polarisation

# %%
fig, ax = plt.subplots(subplot_kw={'aspect': 'equal'}, figsize = (8,6))

ellipse = Ellipse((0, 0), 4, 2, angle=45., fill = False, color = "black", linestyle = "dotted")
ax.add_artist(ellipse)
ellipse = Ellipse((0, 0), 4, 2, angle=135., fill = False, color = "black")
ax.add_artist(ellipse)
ellipse = Ellipse((2.25, 2.25), 0.4, 0.4, angle=90., fill = False, color = "black")
ax.add_artist(ellipse)
ellipse = Ellipse((2.25, 2.25), 0.1, 0.1, angle=90., fill = True, color = "black")
ax.add_artist(ellipse)

# Move left y-axis and bottom x-axis to centre, passing through (0,0)
ax.spines['left'].set_position('center')
ax.spines['bottom'].set_position('center')

# Eliminate upper and right axes
ax.spines['right'].set_color('none')
ax.spines['top'].set_color('none')

plt.tick_params(left = False, bottom = False, labelleft=False, labelbottom = False)

lim = 2.5
dx = 0.1
ax.set_xlim(-lim, lim)
ax.set_ylim(-lim, lim)
ax.arrow(lim-dx, 0., dx, 0., width = 0.1, head_width=0.1, head_length=0.1, length_includes_head=True, color="black")
ax.arrow(0, lim-dx, 0., dx, width = 0.1, head_width=0.1, head_length=0.1, length_includes_head=True, color="black")
plt.annotate("X", (lim, -1*dx))
plt.annotate("Y", (-2*dx, lim))
plt.annotate("tensor-cross", (0.75, -lim))

#plt.axis('off')

plt.savefig("./Cross_polarisation.pdf")
plt.savefig("./Cross_polarisation.svg")
plt.show()
plt.close()

# %% [markdown]
# ### Vector x

# %%
fig, ax = plt.subplots(subplot_kw={'aspect': 'equal'}, figsize = (8,6))

ellipse = Ellipse((0, 0), 4, 2, angle=45., fill = False, color = "black")
ax.add_artist(ellipse)
ellipse = Ellipse((0, 0), 4, 2, angle=135., fill = False, color = "black", linestyle = "dotted")
ax.add_artist(ellipse)

# Move left y-axis and bottom x-axis to centre, passing through (0,0)
ax.spines['left'].set_position('center')
ax.spines['bottom'].set_position('center')

# Eliminate upper and right axes
ax.spines['right'].set_color('none')
ax.spines['top'].set_color('none')

plt.tick_params(left = False, bottom = False, labelleft=False, labelbottom = False)

lim = 2.5
dx = 0.1
ax.set_xlim(-lim, lim)
ax.set_ylim(-lim, lim)
ax.arrow(lim-dx, 0., dx, 0., width = 0.1, head_width=0.1, head_length=0.1, length_includes_head=True, color = "black")
ax.arrow(0, lim-dx, 0., dx, width = 0.1, head_width=0.1, head_length=0.1, length_includes_head=True, color = "black")
plt.arrow(lim-dx, lim-dx, -5*dx,0., width = 0., head_width=0.1, head_length=0.1, length_includes_head=True, color = "black")

plt.annotate("Z", (lim, -1*dx))
plt.annotate("X", (-3*dx, lim))
plt.annotate("vector-X", (0.75, -lim))

#plt.axis('off')

plt.savefig("./Vector_X_polarisation.pdf")
plt.savefig("./Vector_X_polarisation.svg")
plt.show()
plt.close()

# %% [markdown]
# ### Vector y

# %%
fig, ax = plt.subplots(subplot_kw={'aspect': 'equal'}, figsize = (8,6))

ellipse = Ellipse((0, 0), 4, 2, angle=45., fill = False, color = "black")
ax.add_artist(ellipse)
ellipse = Ellipse((0, 0), 4, 2, angle=135., fill = False, color = "black", linestyle = "dotted")
ax.add_artist(ellipse)


# Move left y-axis and bottom x-axis to centre, passing through (0,0)
ax.spines['left'].set_position('center')
ax.spines['bottom'].set_position('center')

# Eliminate upper and right axes
ax.spines['right'].set_color('none')
ax.spines['top'].set_color('none')

plt.tick_params(left = False, bottom = False, labelleft=False, labelbottom = False)

lim = 2.5
dx = 0.1
ax.set_xlim(-lim, lim)
ax.set_ylim(-lim, lim)
ax.arrow(lim-dx, 0., dx, 0., width = 0.1, head_width=0.1, head_length=0.1, length_includes_head=True, color = "black")
ax.arrow(0, lim-dx, 0., dx, width = 0.1, head_width=0.1, head_length=0.1, length_includes_head=True, color = "black")
plt.arrow(lim-dx, lim-dx, -5*dx,0., width = 0., head_width=0.1, head_length=0.1, length_includes_head=True, color = "black")

plt.annotate("$Z$", (lim, -1*dx))
plt.annotate("$Y$", (-2*dx, lim))
plt.annotate(r"vector-$Y$", (0.75, -lim))

#plt.axis('off')

plt.savefig("./Vector_Y_polarisation.pdf")
plt.savefig("./Vector_Y_polarisation.svg")
plt.show()
plt.close()

# %% [markdown]
# ### Scalar-transverse

# %%
fig, ax = plt.subplots(subplot_kw={'aspect': 'equal'}, figsize = (8,6))

ellipse = Ellipse((0, 0), 4, 4, angle=45., fill = False, color = "black", linestyle = "dotted")
ax.add_artist(ellipse)
ellipse = Ellipse((0, 0), 2, 2, angle=135., fill = False, color = "black")
ax.add_artist(ellipse)
ellipse = Ellipse((2.25, 2.25), 0.4, 0.4, angle=90., fill = False, color = "black")
ax.add_artist(ellipse)
ellipse = Ellipse((2.25, 2.25), 0.1, 0.1, angle=90., fill = True, color = "black")
ax.add_artist(ellipse)

# Move left y-axis and bottom x-axis to centre, passing through (0,0)
ax.spines['left'].set_position('center')
ax.spines['bottom'].set_position('center')

# Eliminate upper and right axes
ax.spines['right'].set_color('none')
ax.spines['top'].set_color('none')

plt.tick_params(left = False, bottom = False, labelleft=False, labelbottom = False)

lim = 2.5
dx = 0.1
ax.set_xlim(-lim, lim)
ax.set_ylim(-lim, lim)
ax.arrow(lim-dx, 0., dx, 0., width = 0.1, head_width=0.1, head_length=0.1, length_includes_head=True, color = "black")
ax.arrow(0, lim-dx, 0., dx, width = 0.1, head_width=0.1, head_length=0.1, length_includes_head=True, color = "black")

plt.annotate("$X$", (lim, -1*dx))
plt.annotate("$Y$", (-2*dx, lim))
plt.annotate("scalar-transverse", (0.5, -lim))

#plt.axis('off')

plt.savefig("./Scalar_transverse_polarisation.pdf")
plt.savefig("./Scalar_transverse_polarisation.svg")
plt.show()
plt.close()

# %% [markdown]
# ### Scalar-longitudinal

# %%
fig, ax = plt.subplots(subplot_kw={'aspect': 'equal'}, figsize = (8,6))

ellipse = Ellipse((0, 0), 2, 2, angle=0., fill = False, color = "black")
ax.add_artist(ellipse)
ellipse = Ellipse((0, 0), 4, 2, angle=0., fill = False, color = "black", linestyle = "dotted")
ax.add_artist(ellipse)

# Move left y-axis and bottom x-axis to centre, passing through (0,0)
ax.spines['left'].set_position('center')
ax.spines['bottom'].set_position('center')

# Eliminate upper and right axes
ax.spines['right'].set_color('none')
ax.spines['top'].set_color('none')

plt.tick_params(left = False, bottom = False, labelleft=False, labelbottom = False)

lim = 2.5
dx = 0.1
ax.set_xlim(-lim, lim)
ax.set_ylim(-lim, lim)
ax.arrow(lim-dx, 0., dx, 0., width = 0.1, head_width=0.1, head_length=0.1, length_includes_head=True, color = "black")
ax.arrow(0, lim-dx, 0., dx, width = 0.1, head_width=0.1, head_length=0.1, length_includes_head=True, color = "black")
plt.arrow(lim-dx, lim-dx, -5*dx,0., width = 0., head_width=0.1, head_length=0.1, length_includes_head=True, color = "black")

plt.annotate("$Z$", (lim, -1*dx))
plt.annotate("$X$ or $Y$", (-5*dx, lim))
plt.annotate("scalar-longitudinal", (0.05, -lim))

#plt.axis('off')

plt.savefig("./Scalar_longitudinal_polarisation.pdf")
plt.savefig("./Scalar_longitudinal_polarisation.svg")
plt.show()
plt.close()

# %% [markdown]
# ## Combine in two figures

# %% [markdown]
# ### Tensor polarisations

# %%
fig, (ax_plus, ax_cross) = plt.subplots(nrows = 1, ncols = 2, subplot_kw={'aspect': 'equal'}, figsize = (16,6))

ellipse = Ellipse((0, 0), 4, 2, angle=0., fill = False, color = "black")
ax_plus.add_artist(ellipse)
ellipse = Ellipse((0, 0), 4, 2, angle=90., fill = False, color = "black", linestyle = "dotted")
ax_plus.add_artist(ellipse)
ellipse = Ellipse((2.25, 2.25), 0.4, 0.4, angle=90., fill = False, color = "black")
ax_plus.add_artist(ellipse)
ellipse = Ellipse((2.25, 2.25), 0.1, 0.1, angle=90., fill = True, color = "black")
ax_plus.add_artist(ellipse)

# Move left y-axis and bottom x-axis to centre, passing through (0,0)
ax_plus.spines['left'].set_position('center')
ax_plus.spines['bottom'].set_position('center')

# Eliminate upper and right axes
ax_plus.spines['right'].set_color('none')
ax_plus.spines['top'].set_color('none')

ax_plus.tick_params(left = False, bottom = False, labelleft=False, labelbottom = False)

lim = 2.5
dx = 0.1
ax_plus.set_xlim(-lim, lim)
ax_plus.set_ylim(-lim, lim)
ax_plus.arrow(lim-dx, 0., dx, 0., width = 0.1, head_width=0.1, head_length=0.1, length_includes_head=True, color="black")
ax_plus.arrow(0, lim-dx, 0., dx, width = 0.1, head_width=0.1, head_length=0.1, length_includes_head=True, color="black")
ax_plus.annotate("X", (lim, -1*dx))
ax_plus.annotate("Y", (-2*dx, lim))
ax_plus.annotate("tensor-plus", (0.5, -lim))


ellipse = Ellipse((0, 0), 4, 2, angle=45., fill = False, color = "black", linestyle = "dotted")
ax_cross.add_artist(ellipse)
ellipse = Ellipse((0, 0), 4, 2, angle=135., fill = False, color = "black")
ax_cross.add_artist(ellipse)
ellipse = Ellipse((2.25, 2.25), 0.4, 0.4, angle=90., fill = False, color = "black")
ax_cross.add_artist(ellipse)
ellipse = Ellipse((2.25, 2.25), 0.1, 0.1, angle=90., fill = True, color = "black")
ax_cross.add_artist(ellipse)

# Move left y-axis and bottom x-axis to centre, passing through (0,0)
ax_cross.spines['left'].set_position('center')
ax_cross.spines['bottom'].set_position('center')

# Eliminate upper and right axes
ax_cross.spines['right'].set_color('none')
ax_cross.spines['top'].set_color('none')

ax_cross.tick_params(left = False, bottom = False, labelleft=False, labelbottom = False)

lim = 2.5
dx = 0.1
ax_cross.set_xlim(-lim, lim)
ax_cross.set_ylim(-lim, lim)
ax_cross.arrow(lim-dx, 0., dx, 0., width = 0.1, head_width=0.1, head_length=0.1, length_includes_head=True, color="black")
ax_cross.arrow(0, lim-dx, 0., dx, width = 0.1, head_width=0.1, head_length=0.1, length_includes_head=True, color="black")
ax_cross.annotate("X", (lim, -1*dx))
ax_cross.annotate("Y", (-2*dx, lim))
ax_cross.annotate("tensor-cross", (0.5, -lim))


plt.savefig("./Tensor_polarisations.pdf", bbox_inches = "tight")
#plt.savefig("./Tensor_polarisations.svg")
plt.show()
plt.close()

# %% [markdown]
# ### Extra polarisations

# %%
fig, ((ax_X, ax_Y),(ax_breath, ax_lon)) = plt.subplots(nrows = 2, ncols = 2, subplot_kw={'aspect': 'equal'},\
                                                       figsize = (16,12))

ellipse = Ellipse((0, 0), 4, 2, angle=45., fill = False, color = "black")
ax_X.add_artist(ellipse)
ellipse = Ellipse((0, 0), 4, 2, angle=135., fill = False, color = "black", linestyle = "dotted")
ax_X.add_artist(ellipse)

# Move left y-axis and bottom x-axis to centre, passing through (0,0)
ax_X.spines['left'].set_position('center')
ax_X.spines['bottom'].set_position('center')

# Eliminate upper and right axes
ax_X.spines['right'].set_color('none')
ax_X.spines['top'].set_color('none')

ax_X.tick_params(left = False, bottom = False, labelleft=False, labelbottom = False)

lim = 2.5
dx = 0.1
ax_X.set_xlim(-lim, lim)
ax_X.set_ylim(-lim, lim)
ax_X.arrow(lim-dx, 0., dx, 0., width = 0.1, head_width=0.1, head_length=0.1, length_includes_head=True, color = "black")
ax_X.arrow(0, lim-dx, 0., dx, width = 0.1, head_width=0.1, head_length=0.1, length_includes_head=True, color = "black")
ax_X.arrow(lim-dx, lim-dx, -5*dx,0., width = 0., head_width=0.1, head_length=0.1, length_includes_head=True, color = "black")

ax_X.annotate("Z", (lim, -1*dx))
ax_X.annotate("X", (-3*dx, lim))
ax_X.annotate("vector-X", (0.75, -lim))

#plt.axis('off')


ellipse = Ellipse((0, 0), 4, 2, angle=45., fill = False, color = "black")
ax_Y.add_artist(ellipse)
ellipse = Ellipse((0, 0), 4, 2, angle=135., fill = False, color = "black", linestyle = "dotted")
ax_Y.add_artist(ellipse)


# Move left y-axis and bottom x-axis to centre, passing through (0,0)
ax_Y.spines['left'].set_position('center')
ax_Y.spines['bottom'].set_position('center')

# Eliminate upper and right axes
ax_Y.spines['right'].set_color('none')
ax_Y.spines['top'].set_color('none')

ax_Y.tick_params(left = False, bottom = False, labelleft=False, labelbottom = False)

lim = 2.5
dx = 0.1
ax_Y.set_xlim(-lim, lim)
ax_Y.set_ylim(-lim, lim)
ax_Y.arrow(lim-dx, 0., dx, 0., width = 0.1, head_width=0.1, head_length=0.1, length_includes_head=True, color = "black")
ax_Y.arrow(0, lim-dx, 0., dx, width = 0.1, head_width=0.1, head_length=0.1, length_includes_head=True, color = "black")
ax_Y.arrow(lim-dx, lim-dx, -5*dx,0., width = 0., head_width=0.1, head_length=0.1, length_includes_head=True, color = "black")

ax_Y.annotate("$Z$", (lim, -1*dx))
ax_Y.annotate("$Y$", (-2*dx, lim))
ax_Y.annotate(r"vector-$Y$", (0.75, -lim))


ellipse = Ellipse((0, 0), 4, 4, angle=45., fill = False, color = "black", linestyle = "dotted")
ax_breath.add_artist(ellipse)
ellipse = Ellipse((0, 0), 2, 2, angle=135., fill = False, color = "black")
ax_breath.add_artist(ellipse)
ellipse = Ellipse((2.25, 2.25), 0.4, 0.4, angle=90., fill = False, color = "black")
ax_breath.add_artist(ellipse)
ellipse = Ellipse((2.25, 2.25), 0.1, 0.1, angle=90., fill = True, color = "black")
ax_breath.add_artist(ellipse)

# Move left y-axis and bottom x-axis to centre, passing through (0,0)
ax_breath.spines['left'].set_position('center')
ax_breath.spines['bottom'].set_position('center')

# Eliminate upper and right axes
ax_breath.spines['right'].set_color('none')
ax_breath.spines['top'].set_color('none')

ax_breath.tick_params(left = False, bottom = False, labelleft=False, labelbottom = False)

lim = 2.5
dx = 0.1
ax_breath.set_xlim(-lim, lim)
ax_breath.set_ylim(-lim, lim)
ax_breath.arrow(lim-dx, 0., dx, 0., width = 0.1, head_width=0.1, head_length=0.1, length_includes_head=True, color = "black")
ax_breath.arrow(0, lim-dx, 0., dx, width = 0.1, head_width=0.1, head_length=0.1, length_includes_head=True, color = "black")

ax_breath.annotate("$X$", (lim, -1*dx))
ax_breath.annotate("$Y$", (-2*dx, lim))
ax_breath.annotate("scalar-transverse", (0.5, -lim))


ellipse = Ellipse((0, 0), 2, 2, angle=0., fill = False, color = "black")
ax_lon.add_artist(ellipse)
ellipse = Ellipse((0, 0), 4, 2, angle=0., fill = False, color = "black", linestyle = "dotted")
ax_lon.add_artist(ellipse)

# Move left y-axis and bottom x-axis to centre, passing through (0,0)
ax_lon.spines['left'].set_position('center')
ax_lon.spines['bottom'].set_position('center')

# Eliminate upper and right axes
ax_lon.spines['right'].set_color('none')
ax_lon.spines['top'].set_color('none')

ax_lon.tick_params(left = False, bottom = False, labelleft=False, labelbottom = False)

lim = 2.5
dx = 0.1
ax_lon.set_xlim(-lim, lim)
ax_lon.set_ylim(-lim, lim)
ax_lon.arrow(lim-dx, 0., dx, 0., width = 0.1, head_width=0.1, head_length=0.1, length_includes_head=True, color = "black")
ax_lon.arrow(0, lim-dx, 0., dx, width = 0.1, head_width=0.1, head_length=0.1, length_includes_head=True, color = "black")
ax_lon.arrow(lim-dx, lim-dx, -5*dx,0., width = 0., head_width=0.1, head_length=0.1, length_includes_head=True, color = "black")

ax_lon.annotate("$Z$", (lim, -1*dx))
ax_lon.annotate("$X$ or $Y$", (-5.5*dx, lim))
ax_lon.annotate("scalar-longitudinal", (0.05, -lim))

plt.savefig("./Extra_polarisations.pdf", bbox_inches = "tight")
#plt.savefig("./Vector_X_polarisations.svg")
plt.show()
plt.close()
