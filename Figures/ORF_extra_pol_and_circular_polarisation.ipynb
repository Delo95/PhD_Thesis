# %%
import numpy as np
import matplotlib
import matplotlib.pyplot as plt

# %%
# Parameters for matplotlib (these should be the same as the ones used for SHD)
fontsize = 20
matplotlib.rcParams.update({
    "font.size": fontsize,
    "axes.titlesize": fontsize,
    "axes.labelsize": fontsize, #* 2,
    "xtick.labelsize": fontsize,
    "ytick.labelsize": fontsize,
    "xtick.major.size": fontsize * .8,
    "ytick.major.size": fontsize * .8,
    "legend.fontsize": fontsize,
    #"font.family": "Times new Roman",
    "figure.dpi": 100,
    "savefig.dpi": 300,
    #"text.usetex": True,
    "path.simplify": True,
    "figure.figsize": (8, 6)
})

plt.rcParams["figure.facecolor"] = "w"


# Class to deal in an easy way with number of digits in colorbars (used for ULs and sigma maps)
class FormatScalarFormatter(matplotlib.ticker.ScalarFormatter):
            def __init__(self, fformat="%1.1f", offset=True, mathText=True):
                self.fformat = fformat
                matplotlib.ticker.ScalarFormatter.__init__(self,useOffset=offset,
                                                        useMathText=mathText)
            def _set_format(self):
                self.format = self.fformat
                if self._useMathText:
                    #self.format = '$%s$' % matplotlib.ticker._mathdefault(self.format)
                    self.format = '$%s$' % ('\\mathdefault{%s}' % self.format)

# %%
ORF_non_GR = np.load("./ORF_full_healpy_non_GR_nside_128.npz", allow_pickle=True)
ORF_parity_violation = np.load("ORF_full_healpy_parity_violation_nside_128.npz", allow_pickle=True)

# %% [markdown]
# ## Extra polarisations

# %%
list(ORF_non_GR.keys())
# Out:
# ['freqs',
#  'ORF_HL_tensor',
#  'ORF_HL_vector',
#  'ORF_HL_scalar',
#  'ORF_HV_tensor',
#  'ORF_HV_vector',
#  'ORF_HV_scalar',
#  'ORF_LV_tensor',
#  'ORF_LV_vector',
#  'ORF_LV_scalar',
#  'ORF_HK_tensor',
#  'ORF_HK_vector',
#  'ORF_HK_scalar',
#  'ORF_LK_tensor',
#  'ORF_LK_vector',
#  'ORF_LK_scalar',
#  'ORF_VK_tensor',
#  'ORF_VK_vector',
#  'ORF_VK_scalar',
#  'ORF_HI_tensor',
#  'ORF_HI_vector',
#  'ORF_HI_scalar',
#  'ORF_LI_tensor',
#  'ORF_LI_vector',
#  'ORF_LI_scalar',
#  'ORF_VI_tensor',
#  'ORF_VI_vector',
#  'ORF_VI_scalar',
#  'ORF_KI_tensor',
#  'ORF_KI_vector',
#  'ORF_KI_scalar']

# %% [markdown]
# ### IJ vector, IJ scalar

# %%
plt.plot(ORF_non_GR["freqs"], ORF_non_GR["ORF_HL_vector"], label = "HL vector", color = "blue")
plt.plot(ORF_non_GR["freqs"], ORF_non_GR["ORF_HV_vector"], label = "HV vector", color = "red")
plt.plot(ORF_non_GR["freqs"], ORF_non_GR["ORF_LV_vector"], label = "LV vector", color = "green")
plt.xlim(0, 200)
plt.ylim(-1, 0.3)

plt.grid()
plt.legend()
plt.show()

# %%
plt.plot(ORF_non_GR["freqs"], ORF_non_GR["ORF_HL_scalar"], label = "HL scalar", color = "blue")
plt.plot(ORF_non_GR["freqs"], ORF_non_GR["ORF_HV_scalar"], label = "HV scalar", color = "red")
plt.plot(ORF_non_GR["freqs"], ORF_non_GR["ORF_LV_scalar"], label = "LV scalar", color = "green")
plt.xlim(0, 200)
plt.ylim(-1, 0.5)

plt.grid()
plt.legend()
plt.show()

# %%
plt.plot(ORF_non_GR["freqs"], ORF_non_GR["ORF_HK_vector"], label = "HK vector", color = "blue")
plt.plot(ORF_non_GR["freqs"], ORF_non_GR["ORF_VK_vector"], label = "VK vector", color = "red")
plt.plot(ORF_non_GR["freqs"], ORF_non_GR["ORF_LK_vector"], label = "LK vector", color = "green")
plt.xlim(0, 200)
plt.ylim(-0.4, 0.5)

plt.grid()
plt.legend()
plt.show()

# %%
plt.plot(ORF_non_GR["freqs"], ORF_non_GR["ORF_HK_scalar"], label = "HK scalar", color = "blue")
plt.plot(ORF_non_GR["freqs"], ORF_non_GR["ORF_LK_scalar"], label = "LK scalar", color = "red")
plt.plot(ORF_non_GR["freqs"], ORF_non_GR["ORF_VK_scalar"], label = "VK scalar", color = "green")
plt.xlim(0, 200)
plt.ylim(-0.4, 0.5)

plt.grid()
plt.legend()
plt.show()

# %% [markdown]
# #### Unique figure

# %%
fig, ((ax_HLV_vector, ax_HLVK_vector),(ax_HLV_scalar, ax_HLVK_scalar)) = plt.subplots(nrows = 2, ncols = 2,\
                                                       figsize = (16,12))


ax_HLV_vector.plot(ORF_non_GR["freqs"], ORF_non_GR["ORF_HL_vector"], label = "HL vector", color = "blue")
ax_HLV_vector.plot(ORF_non_GR["freqs"], ORF_non_GR["ORF_HV_vector"], label = "HV vector", color = "red")
ax_HLV_vector.plot(ORF_non_GR["freqs"], ORF_non_GR["ORF_LV_vector"], label = "LV vector", color = "green")
ax_HLV_vector.set_xlim(0, 200)
ax_HLV_vector.set_ylim(-1, 0.3)

ax_HLV_vector.set_ylabel(r"$\gamma_{IJ}^{(V)}(f)$")

ax_HLV_vector.grid()
ax_HLV_vector.legend()


ax_HLV_scalar.plot(ORF_non_GR["freqs"], ORF_non_GR["ORF_HL_scalar"], label = "HL scalar", color = "blue")
ax_HLV_scalar.plot(ORF_non_GR["freqs"], ORF_non_GR["ORF_HV_scalar"], label = "HV scalar", color = "red")
ax_HLV_scalar.plot(ORF_non_GR["freqs"], ORF_non_GR["ORF_LV_scalar"], label = "LV scalar", color = "green")
ax_HLV_scalar.set_xlim(0, 200)
ax_HLV_scalar.set_ylim(-1, 0.5)

ax_HLV_scalar.set_xlabel("Frequency [Hz]")
ax_HLV_scalar.set_ylabel(r"$\gamma_{IJ}^{(S)}(f)$")

ax_HLV_scalar.grid()
ax_HLV_scalar.legend()



ax_HLVK_vector.plot(ORF_non_GR["freqs"], ORF_non_GR["ORF_HK_vector"], label = "HK vector", color = "blue")
ax_HLVK_vector.plot(ORF_non_GR["freqs"], ORF_non_GR["ORF_VK_vector"], label = "VK vector", color = "red")
ax_HLVK_vector.plot(ORF_non_GR["freqs"], ORF_non_GR["ORF_LK_vector"], label = "LK vector", color = "green")
ax_HLVK_vector.set_xlim(0, 200)
ax_HLVK_vector.set_ylim(-0.4, 0.5)

ax_HLVK_vector.grid()
ax_HLVK_vector.legend(loc = 'lower right')


ax_HLVK_scalar.plot(ORF_non_GR["freqs"], ORF_non_GR["ORF_HK_scalar"], label = "HK scalar", color = "blue")
ax_HLVK_scalar.plot(ORF_non_GR["freqs"], ORF_non_GR["ORF_LK_scalar"], label = "LK scalar", color = "red")
ax_HLVK_scalar.plot(ORF_non_GR["freqs"], ORF_non_GR["ORF_VK_scalar"], label = "VK scalar", color = "green")
ax_HLVK_scalar.set_xlim(0, 200)
ax_HLVK_scalar.set_ylim(-0.4, 0.5)

ax_HLVK_scalar.set_xlabel("Frequency [Hz]")

ax_HLVK_scalar.grid()
ax_HLVK_scalar.legend(loc = 'lower right')

plt.savefig("./ORF_extra_pols.pdf", bbox_inches = "tight")
plt.show()

# %% [markdown]
# ### IJ SVT

# %%
plt.plot(ORF_non_GR["freqs"], ORF_non_GR["ORF_HL_tensor"], label = "HL tensor", color = "blue")
plt.plot(ORF_non_GR["freqs"], ORF_non_GR["ORF_HL_vector"], label = "HL vector", color = "red")
plt.plot(ORF_non_GR["freqs"], ORF_non_GR["ORF_HL_scalar"], label = "HL scalar", color = "green")
plt.xlim(0, 200)
plt.ylim(-1, 0.5)

plt.grid()
plt.legend()
plt.show()

# %%
plt.plot(ORF_non_GR["freqs"], ORF_non_GR["ORF_HV_tensor"], label = "HV tensor", color = "blue")
plt.plot(ORF_non_GR["freqs"], ORF_non_GR["ORF_HV_vector"], label = "HV vector", color = "red")
plt.plot(ORF_non_GR["freqs"], ORF_non_GR["ORF_HV_scalar"], label = "HV scalar", color = "green")
plt.xlim(0, 200)
plt.ylim(-0.3, 0.4)

plt.grid()
plt.legend()
plt.show()

# %%
plt.plot(ORF_non_GR["freqs"], ORF_non_GR["ORF_LV_tensor"], label = "LV tensor", color = "blue")
plt.plot(ORF_non_GR["freqs"], ORF_non_GR["ORF_LV_vector"], label = "LV vector", color = "red")
plt.plot(ORF_non_GR["freqs"], ORF_non_GR["ORF_LV_scalar"], label = "LV scalar", color = "green")
plt.xlim(0, 200)
plt.ylim(-0.3, 0.2)

plt.grid()
plt.legend()
plt.show()

# %%
plt.plot(ORF_non_GR["freqs"], ORF_non_GR["ORF_HK_tensor"], label = "HK tensor", color = "blue")
plt.plot(ORF_non_GR["freqs"], ORF_non_GR["ORF_HK_vector"], label = "HK vector", color = "red")
plt.plot(ORF_non_GR["freqs"], ORF_non_GR["ORF_HK_scalar"], label = "HK scalar", color = "green")
plt.xlim(0, 200)
plt.ylim(-0.2, 0.5)

plt.grid()
plt.legend()
plt.show()

# %%
plt.plot(ORF_non_GR["freqs"], ORF_non_GR["ORF_LK_tensor"], label = "LK tensor", color = "blue")
plt.plot(ORF_non_GR["freqs"], ORF_non_GR["ORF_LK_vector"], label = "LK vector", color = "red")
plt.plot(ORF_non_GR["freqs"], ORF_non_GR["ORF_LK_scalar"], label = "LK scalar", color = "green")
plt.xlim(0, 200)
plt.ylim(-0.3, 0.1)

plt.grid()
plt.legend()
plt.show()

# %%
plt.plot(ORF_non_GR["freqs"], ORF_non_GR["ORF_VK_tensor"], label = "VK tensor", color = "blue")
plt.plot(ORF_non_GR["freqs"], ORF_non_GR["ORF_VK_vector"], label = "VK vector", color = "red")
plt.plot(ORF_non_GR["freqs"], ORF_non_GR["ORF_VK_scalar"], label = "VK scalar", color = "green")
plt.xlim(0, 200)
plt.ylim(-0.4, 0.3)

plt.grid()
plt.legend()
plt.show()

# %% [markdown]
# ## Circular polarisation

# %%
list(ORF_parity_violation.keys())
# Out:
# ['freqs',
#  'ORF_HL_I',
#  'ORF_HL_V',
#  'ORF_HV_I',
#  'ORF_HV_V',
#  'ORF_LV_I',
#  'ORF_LV_V',
#  'ORF_HK_I',
#  'ORF_HK_V',
#  'ORF_LK_I',
#  'ORF_LK_V',
#  'ORF_VK_I',
#  'ORF_VK_V',
#  'ORF_HI_I',
#  'ORF_HI_V',
#  'ORF_LI_I',
#  'ORF_LI_V',
#  'ORF_VI_I',
#  'ORF_VI_V',
#  'ORF_KI_I',
#  'ORF_KI_V']

# %% [markdown]
# ### ORF_V only

# %% [markdown]
# #### Separate figures

# %%
plt.plot(ORF_parity_violation["freqs"], ORF_parity_violation["ORF_HL_V"], label = "HL", color = "blue")
plt.plot(ORF_parity_violation["freqs"], ORF_parity_violation["ORF_HV_V"], label = "HV", color = "red")
plt.plot(ORF_parity_violation["freqs"], ORF_parity_violation["ORF_LV_V"], label = "LV", color = "green")
plt.xlim(0, 200)
plt.ylim(-0.15, 0.15)

plt.grid()
plt.legend()
plt.show()

# %%
plt.plot(ORF_parity_violation["freqs"], ORF_parity_violation["ORF_HK_V"], label = "HK", color = "blue")
plt.plot(ORF_parity_violation["freqs"], ORF_parity_violation["ORF_LK_V"], label = "LK", color = "red")
plt.plot(ORF_parity_violation["freqs"], ORF_parity_violation["ORF_VK_V"], label = "VK", color = "green")
plt.xlim(0, 200)
plt.ylim(-0.4, 0.3)

plt.grid()
plt.legend()
plt.show()

# %% [markdown]
# #### Unique figure

# %%
fig, (ax_HLV_V, ax_HLVK_V) = plt.subplots(nrows = 1, ncols = 2, figsize = (16,6))

ax_HLV_V.plot(ORF_parity_violation["freqs"], ORF_parity_violation["ORF_HL_V"], label = "HL", color = "blue")
ax_HLV_V.plot(ORF_parity_violation["freqs"], ORF_parity_violation["ORF_HV_V"], label = "HV", color = "red")
ax_HLV_V.plot(ORF_parity_violation["freqs"], ORF_parity_violation["ORF_LV_V"], label = "LV", color = "green")
ax_HLV_V.set_xlim(0, 200)
ax_HLV_V.set_ylim(-0.15, 0.15)

ax_HLV_V.set_xlabel("Frequency [Hz]")
ax_HLV_V.set_ylabel(r"$\gamma_{IJ}^{(V)}(f)$")

ax_HLV_V.grid()
ax_HLV_V.legend()


ax_HLVK_V.plot(ORF_parity_violation["freqs"], ORF_parity_violation["ORF_HK_V"], label = "HK", color = "blue")
ax_HLVK_V.plot(ORF_parity_violation["freqs"], ORF_parity_violation["ORF_LK_V"], label = "LK", color = "red")
ax_HLVK_V.plot(ORF_parity_violation["freqs"], ORF_parity_violation["ORF_VK_V"], label = "VK", color = "green")
ax_HLVK_V.set_xlim(0, 200)
ax_HLVK_V.set_ylim(-0.4, 0.3)

ax_HLVK_V.set_xlabel("Frequency [Hz]")

ax_HLVK_V.grid()
ax_HLVK_V.legend()


plt.savefig("./ORF_V.pdf", bbox_inches= "tight")
plt.show()
